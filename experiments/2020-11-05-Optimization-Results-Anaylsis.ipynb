# %%
from plotnine import *

import pyarrow.parquet as pq
import pyarrow as pa
import numpy as np
import pandas as pd

# %%
base_path = '../data/optimization_outputs/2021-05-14/'

# %%
df_1c1m = pq.read_table(base_path + '/1c1m.parquet/').to_pandas()

# There appears to be some mistakes in 2 and 6 -- warrants some later investigation
#df_1c1m = df_1c1m.drop(df_1c1m[df_1c1m['input'] == 3].index)
#df_1c1m = df_1c1m.drop(df_1c1m[df_1c1m['input'] == 4].index)

# %%
df_1c1m.groupby(['n_z', 'n_w']).mean().reset_index().drop('input', axis=1).sort_values(by='p_load_avg', ascending=False).head(10)
# Out:
#       n_z  n_w  p_load_avg
# 3241   72   20    0.000545
# 3143   70   20    0.000544
# 3339   74   20    0.000544
# 3045   68   20    0.000543
# 3144   70   22    0.000543
# 3046   68   22    0.000543
# 3242   72   22    0.000543
# 3437   76   20    0.000542
# 2948   66   22    0.000542
# 2947   66   20    0.000542

# %%
df_1c1m.groupby('input').mean('p_load_avg').sort_values(by='p_load_avg')
# Out:
#        n_z  n_w  p_load_avg
# input
# 1      103  103    0.000101
# 6      103  103    0.000110
# 5      103  103    0.000116
# 0      103  103    0.000118
# 3      103  103    0.000124
# 4      103  103    0.000128
# 2      103  103    0.000186

# %%
p = ggplot(aes(x='factor(n_z)', y='factor(n_w)', fill='p_load_avg'), df_1c1m.groupby(['n_z', 'n_w']).mean().reset_index())
p + geom_tile() + scale_fill_cmap('turbo') + coord_equal() + theme(figure_size=(10, 10), axis_text_x=element_text(angle=90)) + ggtitle('1c1m') + labs(fill=r'$\bar{P}_{\mathrm{load}}$', x='nz', y='nw')
# Out:
# <ggplot: (8738261972213)>

# %%
df_2c1m = pq.read_table(base_path + '2c1m.parquet/').to_pandas()
df_2c1m.head()

# There appears to be some mistakes in 2 and 6 -- warrants some later investigation
#df_2c1m = df_2c1m.drop(df_2c1m[df_2c1m['input'] == 2].index)
#df_2c1m = df_2c1m.drop(df_2c1m[df_2c1m['input'] == 3].index)
#df_2c1m = df_2c1m.drop(df_2c1m[df_2c1m['input'] == 5].index)

df_2c1m.groupby(['n_z', 'n_w']).mean().reset_index().drop('input', axis=1).sort_values(by='p_load_avg', ascending=False).head(10)
# Out:
#       n_z  n_w  p_load_avg
# 2944   66   14    0.000465
# 2846   64   14    0.000465
# 2748   62   14    0.000464
# 3042   68   14    0.000464
# 2749   62   16    0.000464
# 2651   60   16    0.000464
# 2847   64   16    0.000463
# 3140   70   14    0.000463
# 2650   60   14    0.000463
# 2553   58   16    0.000463

# %%
df_2c1m.groupby('input').mean('p_load_avg').sort_values(by='p_load_avg')
# Out:
#        n_z  n_w  p_load_avg
# input
# 1      103  103    0.000069
# 6      103  103    0.000079
# 5      103  103    0.000083
# 0      103  103    0.000085
# 3      103  103    0.000092
# 4      103  103    0.000093
# 2      103  103    0.000138

# %%
p = ggplot(aes(x='factor(n_z)', y='factor(n_w)', fill='p_load_avg'), df_2c1m.groupby(['n_z', 'n_w']).mean().reset_index())
p + geom_tile() + scale_fill_cmap('turbo') + coord_equal() + theme(figure_size=(10, 10), axis_text_x=element_text(angle=90)) + ggtitle('2c1m')
# Out:
# <ggplot: (8738238785045)>

# %%
df_1c2m = pq.read_table(base_path + '1c2m.parquet/').to_pandas()
df_1c2m.head()

# There appears to be some mistakes in 2 and 6 -- warrants some later investigation
#df_1c2m = df_1c2m.drop(df_1c2m[df_1c2m['input'] == 1].index)
# df_1c2m = df_1c2m.drop(df_1c2m[df_1c2m['input'] == 1].index)
#df_1c2m = df_1c2m.drop(df_1c2m[df_1c2m['input'] == 3].index)
#df_1c2m = df_1c2m.drop(df_1c2m[df_1c2m['input'] == 4].index)
# df_1c2m = df_1c2m.drop(df_1c2m[df_1c2m['input'] == 5].index)

df_1c2m.groupby(['n_z', 'n_w']).mean().reset_index().drop('input', axis=1).sort_values(by='p_load_avg', ascending=False).head(10)
# Out:
#       n_z  n_w  p_load_avg
# 3045   68   20    0.001555
# 3143   70   20    0.001555
# 3240   72   18    0.001554
# 3142   70   18    0.001554
# 2947   66   20    0.001553
# 3338   74   18    0.001553
# 3241   72   20    0.001553
# 3044   68   18    0.001551
# 3436   76   18    0.001549
# 2849   64   20    0.001549

# %%
df_1c2m.groupby('input').mean('p_load_avg').sort_values(by='p_load_avg')
# Out:
#        n_z  n_w  p_load_avg
# input
# 2      103  103    0.000283
# 6      103  103    0.000330
# 5      103  103    0.000335
# 0      103  103    0.000364
# 3      103  103    0.000394
# 1      103  103    0.000406
# 4      103  103    0.000475

# %%
p = ggplot(aes(x='factor(n_z)', y='factor(n_w)', fill='p_load_avg'), df_1c2m.groupby(['n_z', 'n_w']).mean().reset_index())
p + geom_tile() + scale_fill_cmap('turbo') + coord_equal() + theme(figure_size=(10, 10), axis_text_x=element_text(angle=90)) + ggtitle('1c2m')
# Out:
# <ggplot: (8738240099109)>

# %%
df_2c2m = pq.read_table(base_path + '2c2m.parquet/').to_pandas()
# There appears to be some mistakes in 2 and 6 -- warrants some later investigation
#df_2c2m = df_2c2m.drop(df_2c2m[df_2c2m['input'] == 4].index)
df_2c2m = df_2c2m.drop(df_2c2m[df_2c2m['input'] == 2].index)

# %%
df_2c2m.groupby('input').mean('p_load_avg').sort_values(by='p_load_avg')
# Out:
#        n_z  n_w  p_load_avg
# input
# 1      103  103    0.000193
# 5      103  103    0.000254
# 6      103  103    0.000263
# 0      103  103    0.000287
# 3      103  103    0.000297
# 4      103  103    0.000307

# %%
df_2c2m.groupby(['n_z', 'n_w']).mean().sort_values(by='p_load_avg', ascending=False).head()
# Out:
#             input  p_load_avg
# n_z n_w
# 60  12   3.166667    0.001364
# 54  14   3.166667    0.001359
# 64  14   3.166667    0.001356
# 58  12   3.166667    0.001356
# 62  14   3.166667    0.001356

# %%
p = ggplot(aes(x='factor(n_z)', y='factor(n_w)', fill='p_load_avg'), df_2c2m.groupby(['n_z', 'n_w']).mean().reset_index())
p + geom_tile() + scale_fill_cmap('turbo') + coord_equal() + theme(figure_size=(12, 12), axis_text_x=element_text(angle=90)) + ggtitle('2c2m')
# Out:
# <ggplot: (8738240895133)>

# %%
df_2c2m.groupby(['n_z', 'n_w']).mean().sort_values(by='p_load_avg', ascending=False)
# Out:
#          input  p_load_avg
# n_z n_w
# 82  14       3    0.000659
# 86  14       3    0.000658
# 84  14       3    0.000658
# 78  16       3    0.000656
# 82  16       3    0.000656
# ...        ...         ...
# 196 200      3    0.000018
# 198 200      3    0.000018
# 200 200      3    0.000018
# 8   6        3    0.000016
# 6   6        3    0.000009
#
# [9604 rows x 2 columns]
